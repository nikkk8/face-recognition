# %%
import cv2
import os
import face_recognition as fr
import numpy as np

# %%
path='images'

# %%
mylist=os.listdir(path)
mylist
# Out:
# ['messi.jpg', 'neymar.jpg', 'pedri.jpg', 'pogba.jpg', 'ronaldo.jpg']

# %%
imgs=[]
classnames=[]
for img in mylist:
    imgpath=os.path.join(path,img)
    print(imgpath)
    current_img=cv2.imread(imgpath)
    imgs.append(current_img)
    classnames.append(img.split(".")[0])
print(len(imgs))
print(classnames)
# Out:
# images\messi.jpg
# images\neymar.jpg
# images\pedri.jpg
# images\pogba.jpg
# images\ronaldo.jpg
# 5
# ['messi', 'neymar', 'pedri', 'pogba', 'ronaldo']

# %%
def faceencoding(images):
    encodedlist=[]
    for img in images:
        img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        face_in_frame=fr.face_locations(img1)
        encode=fr.face_encodings(img1,face_in_frame)[0]
        #print(face_in_frame)
        #print(encode)
        encodedlist.append(encode)
    return encodedlist

# %%
encoded_list_knownFaces=faceencoding(imgs)
encoded_list_knownFaces
# Out:
# [array([-0.16965024,  0.14365873,  0.03713674, -0.02495728, -0.11662358,
#          0.10020726, -0.04542699, -0.04811674,  0.1280044 , -0.04963356,
#          0.25728482,  0.00593487, -0.35403818, -0.00629526, -0.03596703,
#          0.11941665, -0.14485757, -0.01671336, -0.1373509 , -0.19183043,
#         -0.0278706 ,  0.13100114,  0.00387405,  0.024983  , -0.14121963,
#         -0.2739518 ,  0.01217313, -0.17646323,  0.06395024, -0.14710514,
#          0.00523447,  0.07309307, -0.08704846, -0.05104321,  0.04408039,
#          0.0293804 ,  0.00335223, -0.08953694,  0.2153475 , -0.08742842,
#         -0.0480739 , -0.00211797,  0.13012207,  0.26683649,  0.08138493,
#          0.00431354,  0.04062252, -0.06629547,  0.1899883 , -0.21671727,
#          0.09721327,  0.10747895,  0.12873429,  0.08963943,  0.06531955,
#         -0.23868233, -0.020104  ,  0.17912194, -0.20671755,  0.11256728,
#          0.0975024 ,  0.00063642, -0.10488285, -0.08914883,  0.22334416,
#          0.1233324 , -0.16990268, -0.17108265,  0.09964535, -0.14068919,
#         -0.04856724,  0.07187275, -0.15074217, -0.15073487, -0.2155994 ,
#          0.15166837,  0.32180417,  0.19528943, -0.15963989, -0.00628781,
#         -0.04491446, -0.05817343,  0.00328126,  0.06361561, -0.11551411,
#         -0.09907377,  0.00877341, -0.00054308,  0.17751279,  0.07515793,
#         -0.06362963,  0.24182835,  0.06473668, -0.04100434,  0.00695709,
#          0.01981443, -0.17828523, -0.10335419, -0.07482918,  0.00597231,
#         -0.00268804, -0.13263483,  0.01224902,  0.0923273 , -0.17540225,
#          0.19449899, -0.06075438,  0.02886013,  0.04223899,  0.04564287,
#         -0.09934872, -0.01106576,  0.21757303, -0.25137791,  0.19091852,
#          0.10292073,  0.13631313,  0.17504166,  0.10747566,  0.11134165,
#          0.05390161,  0.09336039, -0.15931034, -0.15428086,  0.12250774,
1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    face_in_frame=fr.face_locations(img1)
    # print(face_in_frame)
    encoded_faces=fr.face_encodings(img1,face_in_frame)
    # print(encoded_faces)
    for encfc,faceloc in zip(encoded_faces,face_in_frame):
        matches=fr.compare_faces(encoded_list_knownFaces,encfc)
        print(matches)
        facedistance=fr.face_distance(encoded_list_knownFaces,encfc)
        print(facedistance)
        matchind=np.argmin(facedistance)
        print(matchind)
        if matches[matchind]==True:
            name=classnames[matchind]
            print(name)
            y1,x2,y2,x1=faceloc
            cv2.rectangle(img,(x1, y1),(x2, y2),(0,255,0),2)
            cv2.putText(img,name,(x1, y1),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)

    cv2.imshow("WEBCAM",img)
    if cv2.waitKey(1)&0XFF==ord('q'):
        break
video.release()
cv2.destroyAllWindows()
# Out:
# [True, False, False, False, False]
# [0.58676244 0.7354056  0.74097944 0.90361409 0.77229354]
# 0
# messi
# [True, False, False, False, False]
# [0.51655791 0.66671019 0.78336063 0.92563003 0.78641432]
# 0
# messi
# [False, False, False, False, False]
# [0.62466684 0.68459255 0.68126665 0.81642256 0.67924722]
# 0
# [False, False, False, False, False]
# [0.85751013 0.66378501 0.72040905 0.62089155 0.71926504]
# 3
# [True, False, False, False, False]
# [0.54486709 0.70833254 0.80006511 0.95507116 0.83002916]
# 0
# messi
# [False, True, False, False, False]
# [0.81926656 0.52732731 0.72542444 0.71451049 0.77812383]
# 1
# neymar
# [True, False, False, False, False]
# [0.5132948  0.74320823 0.78068904 0.96126011 0.83656335]
# 0
# messi
# [False, True, False, False, False]
# [0.82454636 0.45833049 0.71696754 0.77919829 0.75361011]
# 1
# neymar
# [True, False, False, False, False]
# [0.4394362  0.70890858 0.7490039  0.9746819  0.76294924]
# 0
# messi
# [False, True, False, False, False]
# [0.81823539 0.4074704  0.73085728 0.83653336 0.73402561]
# 1
# neymar
# [True, False, False, False, False]
# [0.47003282 0.69895471 0.76532858 0.98627022 0.79245664]
# 0
# messi
# [False, True, False, False, False]
# [0.84692123 0.45743324 0.72859742 0.77079711 0.75566769]
# 1
# neymar
# [False, True, False, False, False]
# [0.82812008 0.47283411 0.69034142 0.77960374 0.75076509]
# 1
# neymar
# [True, False, False, False, False]
# [0.48676864 0.68946993 0.77340508 0.95331593 0.80947398]
# 0
# messi
# [True, False, False, False, False]
# [0.50273143 0.71314686 0.78149199 1.00876402 0.79580852]
# 0
# messi
# [False, True, False, False, False]
# [0.81441775 0.44351546 0.70650895 0.78732702 0.7572962 ]
# 1
# neymar
# [False, True, False, False, False]
# [0.82945405 0.42407544 0.72831811 0.7861967  0.73956178]
# 1
# neymar
# [True, False, False, False, False]
# [0.44355784 0.71066121 0.76520202 0.99573346 0.77585352]
# 0
# messi
# [False, True, False, False, False]
# [0.82269984 0.40441921 0.70747205 0.81385161 0.74571024]
# 1
# neymar
# [True, False, False, False, False]
# [0.45623668 0.70642284 0.76082804 0.99133429 0.7744753 ]
# 0
# messi
# [False, True, False, False, False]
# [0.763038   0.52255723 0.65722557 0.81682619 0.68959825]
# 1
# neymar
# [True, False, False, False, False]
# [0.5296735  0.72256008 0.75865267 0.9468959  0.80421089]
# 0
# messi
# [False, True, False, False, False]
# [0.82182189 0.45760498 0.69713522 0.80710115 0.70629585]
# 1
# neymar
# [True, False, False, False, False]
# [0.4963248  0.67081127 0.77170781 0.95371853 0.7667452 ]
# 0
# messi
# [False, True, False, False, False]
# [0.77531441 0.45602129 0.71840111 0.7948051  0.71778731]
# 1
# neymar
# [True, False, False, False, False]
# [0.49375338 0.69873983 0.78538842 0.95701676 0.82384265]
# 0
# messi
# [False, True, False, False, False]
# [0.79731418 0.42899861 0.72869498 0.78729835 0.75261885]
# 1
# neymar
# [True, False, False, False, False]
# [0.4943079  0.67951109 0.75894794 0.95976081 0.78049545]
# 0
# messi
# [False, True, False, False, False]
# [0.81639259 0.4497604  0.70947822 0.8151294  0.73227575]
# 1
# neymar
# [True, False, False, False, False]
# [0.46791047 0.72115108 0.76242201 0.98319961 0.77731127]
# 0
# messi
# [False, True, False, False, False]
# [0.80627912 0.40181191 0.73993728 0.82669246 0.74866584]
# 1
# neymar
# [True, False, False, False, False]
# [0.46310736 0.74261315 0.75365284 0.98763502 0.77547594]
# 0
# messi
# [False, True, False, False, False]
# [0.79207822 0.47812109 0.69461755 0.80260279 0.73961025]
# 1
# neymar
# [True, False, False, False, False]
# [0.50942583 0.71739089 0.79182272 0.98505621 0.81779696]
# 0
# messi
# [False, True, False, False, False]
# [0.74688914 0.54361245 0.69772821 0.85259155 0.73227294]
# 1
# neymar
# [True, False, False, False, False]
# [0.54662455 0.70272739 0.77793566 0.99202808 0.80459151]
# 0
# messi
# [False, True, False, False, False]
# [0.83258992 0.40848408 0.71402009 0.82759326 0.74878334]
# 1
# neymar
# [True, False, False, False, False]
# [0.47282187 0.72032086 0.76296702 0.98420866 0.79272049]
# 0
# messi
# [False, True, False, False, False]
# [0.83201966 0.44794454 0.7152697  0.78442474 0.74666908]
# 1
# neymar
# [True, False, False, False, False]
# [0.48941071 0.6924143  0.76687727 0.95968649 0.77991293]
# 0
# messi
# [False, True, False, False, False]
# [0.8230753  0.39707607 0.7216922  0.80753011 0.70840326]
# 1
# neymar
# [True, False, False, False, False]
# [0.46262186 0.72499287 0.74440766 0.98380868 0.75971049]
# 0
# messi
# [False, True, False, False, False]
# [0.80578668 0.41846413 0.70812355 0.8349946  0.72055616]
# 1
# neymar
# [True, False, False, False, False]
# [0.47798045 0.73506204 0.75526744 1.00245333 0.78063058]
# 0
# messi
# [False, False, False, False, False]
# [0.76842648 0.63798909 0.69654459 0.81061022 0.76945513]
# 1
# [True, False, False, False, False]
# [0.49675967 0.72052398 0.78643617 0.96049139 0.80528323]
# 0
# messi
